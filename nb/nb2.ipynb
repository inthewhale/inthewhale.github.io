# %%
cd g:\scripts\nb2
# Out:
# g:\scripts\nb2

# %%
ls
# Out:
#  Volume in drive G is HDD3TB
#  Volume Serial Number is 5022-AE56
#
#  Directory of g:\scripts\nb2
#
# 01/23/2018  09:33 PM    <DIR>          .
# 01/23/2018  09:33 PM    <DIR>          ..
# 01/23/2018  09:33 PM        80,436,869 BK.csv
#                1 File(s)     80,436,869 bytes
#                2 Dir(s)  1,977,742,286,848 bytes free

# %%
import pandas as pd

# %%
df_data = pd.read_csv('BK.csv')
# Out:
# c:\python27\lib\site-packages\IPython\core\interactiveshell.py:2718: DtypeWarning: Columns (18,19,21,22,23,24,25,63,64,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277131 entries, 0 to 277130
# Data columns (total 84 columns):
# Borough          277131 non-null object
# Block            277131 non-null int64
# Lot              277131 non-null int64
# CD               277131 non-null int64
# CT2010           276491 non-null float64
# CB2010           274567 non-null float64
# SchoolDist       276810 non-null float64
# Council          276806 non-null float64
# ZipCode          276427 non-null float64
# FireComp         276594 non-null object
# PolicePrct       276743 non-null float64
# HealthArea       276699 non-null float64
# SanitBoro        276082 non-null float64
# SanitDistrict    276086 non-null float64
# SanitSub         272250 non-null object
# Address          276938 non-null object
# ZoneDist1        276976 non-null object
# ZoneDist2        7186 non-null object
# ZoneDist3        75 non-null object
# ZoneDist4        6 non-null object
# Overlay1         35493 non-null object
# ...

# %%
df_data.describe()
# Out:
#                Block            Lot             CD         CT2010  \
# count  277131.000000  277131.000000  277131.000000  276491.000000
# mean     4758.561319     151.568760     310.349304     509.339010
# std      2533.042836     854.219717       5.475192     329.754358
# min         1.000000       1.000000     301.000000       1.000000
# 25%      2318.000000      19.000000     305.000000     240.000000
# 50%      5152.000000      38.000000     311.000000     444.000000
# 75%      6865.000000      61.000000     315.000000     738.000000
# max      8955.000000    9047.000000     410.000000    1522.000000
#
#               CB2010     SchoolDist        Council        ZipCode  \
# count  274567.000000  276810.000000  276806.000000  276427.000000
# mean     1957.006465      19.169708      41.336084   11220.410911
# std       982.569546       3.911379       4.548730      11.214950
# min         1.000000      13.000000      33.000000   11201.000000
# ...

# %%
df_data = pd.read_csv('MN.csv')
# Out:
# c:\python27\lib\site-packages\IPython\core\interactiveshell.py:2718: DtypeWarning: Columns (19,22,23,25,63,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_data.describe()
# Out:
#               Block           Lot            CD        CT2010        CB2010  \
# count  42958.000000  42958.000000  42958.000000  42788.000000  42554.000000
# mean    1228.821919    516.671819    107.098492    133.956052   2677.072473
# std      609.862731   1824.254334      8.164918     75.614324   1657.589351
# min        1.000000      1.000000    101.000000      1.000000      1.000000
# 25%      700.250000     18.000000    104.000000     71.000000   1004.000000
# 50%     1250.000000     37.000000    107.000000    132.000000   2002.000000
# 75%     1755.000000     61.000000    109.000000    194.000000   4000.000000
# max     2255.000000   9220.000000    401.000000    319.000000   9000.000000
#
#          SchoolDist       Council       ZipCode    PolicePrct    HealthArea  \
# count  42853.000000  42861.000000  42801.000000  42851.000000  42829.000000
# mean       2.920566      4.949791  10028.474895     18.262258   4184.775269
# ...

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42958 entries, 0 to 42957
# Data columns (total 84 columns):
# Borough          42958 non-null object
# Block            42958 non-null int64
# Lot              42958 non-null int64
# CD               42958 non-null int64
# CT2010           42788 non-null float64
# CB2010           42554 non-null float64
# SchoolDist       42853 non-null float64
# Council          42861 non-null float64
# ZipCode          42801 non-null float64
# FireComp         42808 non-null object
# PolicePrct       42851 non-null float64
# HealthArea       42829 non-null float64
# SanitBoro        42701 non-null float64
# SanitDistrict    42760 non-null float64
# SanitSub         39842 non-null object
# Address          42881 non-null object
# ZoneDist1        42904 non-null object
# ZoneDist2        3696 non-null object
# ZoneDist3        96 non-null object
# ZoneDist4        5 non-null object
# Overlay1         6319 non-null object
# ...

# %%
df_data.head()
# Out:
#   Borough  Block  Lot   CD  CT2010  CB2010  SchoolDist  Council  ZipCode  \
# 0      MN      1   10  101     5.0  1018.0         2.0      1.0  10004.0
# 1      MN      1  101  101     1.0  1001.0         2.0      1.0  10004.0
# 2      MN      1  201  101     1.0  1000.0         2.0      1.0  10004.0
# 3      MN      1  301  101     NaN     NaN         2.0      1.0  10004.0
# 4      MN      1  401  101     NaN     NaN         2.0      1.0  10004.0
#
#   FireComp   ...      YCoord  ZoneMap  ZMCode   Sanborn   TaxMap EDesigNum  \
# 0     E007   ...    190225.0      16a       Y   199 999  10101.0       NaN
# 1     E007   ...    190636.0      16a       Y   199 999  10101.0       NaN
# 2     E007   ...    193648.0      12b     NaN   199 999  10101.0       NaN
# 3     E007   ...         NaN      12b     NaN   199 999  10101.0       NaN
# 4     E007   ...         NaN      12b     NaN  1 99 999  10101.0       NaN
#
#   APPBBL APPDate PLUTOMapID Version
# 0    0.0     NaN          1    16V2
# ...

# %%
df_data['PolicePrct'].hist(bins=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-80ebe42ec4ed> in <module>()
#       1 df_data['PolicePrct'].hist(bins=20)
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df_landmark = df_data[pd.notnull(df_data['Landmark'])]

# %%
df_landmark.head()
# Out:
#    Borough  Block  Lot   CD  CT2010  CB2010  SchoolDist  Council  ZipCode  \
# 0       MN      1   10  101     5.0  1018.0         2.0      1.0  10004.0
# 1       MN      1  101  101     1.0  1001.0         2.0      1.0  10004.0
# 5       MN      2    1  101     9.0  1025.0         2.0      1.0  10004.0
# 9       MN      3    1  101   319.0  1000.0         2.0      1.0  10004.0
# 24      MN      7   35  101     9.0  1016.0         2.0      1.0  10004.0
#
#    FireComp   ...      YCoord  ZoneMap  ZMCode  Sanborn   TaxMap EDesigNum  \
# 0      E007   ...    190225.0      16a       Y  199 999  10101.0       NaN
# 1      E007   ...    190636.0      16a       Y  199 999  10101.0       NaN
# 5      L015   ...    194440.0      12b     NaN  101N100  10101.0       NaN
# 9      L015   ...    195328.0      12b     NaN  101S087  10101.0       NaN
# 24     L015   ...    195543.0      12b     NaN  101S002  10101.0       NaN
#
#           APPBBL     APPDate PLUTOMapID Version
# ...

# %%
df_landmark.describe()
# Out:
#              Block          Lot          CD      CT2010       CB2010  \
# count   853.000000   853.000000  853.000000  850.000000   846.000000
# mean   1009.507620   472.208675  105.432591  104.846941  2286.281324
# std     581.371954  1755.966644    3.572090   66.808444  1487.923024
# min       1.000000     1.000000  101.000000    1.000000  1000.000000
# 25%     543.000000    11.000000  103.000000   48.000000  1004.000000
# 50%    1030.000000    29.000000  105.000000  102.000000  2000.000000
# 75%    1413.000000    50.000000  108.000000  148.020000  3001.000000
# max    2241.000000  7507.000000  164.000000  319.000000  7000.000000
#
#        SchoolDist     Council       ZipCode  PolicePrct   HealthArea  \
# count  852.000000  852.000000    849.000000  851.000000   851.000000
# mean     2.403756    3.841549  10027.210836   14.971798  4949.920094
# std      1.072631    2.385722     28.985953    9.382169  1994.053801
# ...

# %%
df_landmark.columns
# Out:
# Index([u'Borough', u'Block', u'Lot', u'CD', u'CT2010', u'CB2010',
#        u'SchoolDist', u'Council', u'ZipCode', u'FireComp', u'PolicePrct',
#        u'HealthArea', u'SanitBoro', u'SanitDistrict', u'SanitSub', u'Address',
#        u'ZoneDist1', u'ZoneDist2', u'ZoneDist3', u'ZoneDist4', u'Overlay1',
#        u'Overlay2', u'SPDist1', u'SPDist2', u'SPDist3', u'LtdHeight',
#        u'SplitZone', u'BldgClass', u'LandUse', u'Easements', u'OwnerType',
#        u'OwnerName', u'LotArea', u'BldgArea', u'ComArea', u'ResArea',
#        u'OfficeArea', u'RetailArea', u'GarageArea', u'StrgeArea',
#        u'FactryArea', u'OtherArea', u'AreaSource', u'NumBldgs', u'NumFloors',
#        u'UnitsRes', u'UnitsTotal', u'LotFront', u'LotDepth', u'BldgFront',
#        u'BldgDepth', u'Ext', u'ProxCode', u'IrrLotCode', u'LotType',
#        u'BsmtCode', u'AssessLand', u'AssessTot', u'ExemptLand', u'ExemptTot',
#        u'YearBuilt', u'YearAlter1', u'YearAlter2', u'HistDist', u'Landmark',
# ...

# %%
df_landmark[['Address','Landmark','OwnerName']]
# Out:
#                            Address                             Landmark  \
# 0               1 GOVERNORS ISLAND                      CASTLE WILLIAMS
# 1                 1 LIBERTY ISLAND  STATUE OF LIBERTY NATIONAL MONUMENT
# 5                  MARGINAL STREET            BATTERY MARITIME BUILDING
# 9                  10 BATTERY PARK  BATTERY PARK CONTROL HOUSE (IRT SUB
# 24                 99 BROAD STREET                      FRAUNCES TAVERN
# 34                  7 STATE STREET                   JAMES WATSON HOUSE
# 52                 70 BROAD STREET  AMERICAN BANK NOTE COMPANY OFFICE B
# 59              2 WHITEHALL STREET           UNITED STATES CUSTOM HOUSE
# 60                WHITEHALL STREET                  BOWLING GREEN FENCE
# 61                      1 BROADWAY  INTERNATIONAL MERCANTILE MARINE COM
# 62                     11 BROADWAY       BOWLING GREEN OFFICES BUILDING
# 63                     25 BROADWAY                      CUNARD BUILDING
# ...
